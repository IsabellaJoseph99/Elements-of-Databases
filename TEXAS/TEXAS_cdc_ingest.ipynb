# %%
dataset_id = "cdc_staging"

# %%
############ FOR TEXAS #########

# %%
# !bq --location=US mk --dataset cdc_staging
# Out:
# Dataset 'sunny-advantage-266802:cdc_staging' successfully created.

# %%
# Loading 2011 data onto BQ.

# %%
# !bq \
    --location=US \
    load \
    --autodetect \
    --skip_leading_rows=1 \
    --source_format=CSV \
    {dataset_id}.2011 \
    'gs://the-data-miners-cdc-bucket/the-data-miners-cdc-folder/2011.csv'
# Out:
# Waiting on bqjob_r575904a0354fa07f_000001702b76c68d_1 ... (85s) Current status: DONE

# %%
# Loading 2012 data onto BQ.

# %%
# !bq \
    --location=US \
    load \
    --autodetect \
    --skip_leading_rows=1 \
    --source_format=CSV \
    {dataset_id}.2012 \
    'gs://the-data-miners-cdc-bucket/the-data-miners-cdc-folder/2012.csv'
# Out:
# Waiting on bqjob_r113ab5db00345fd0_000001702b79a10e_1 ... (85s) Current status: DONE

# %%
# Loading 2013 data onto BQ.

# %%
# !bq \
    --location=US \
    load \
    --autodetect \
    --skip_leading_rows=1 \
    --source_format=CSV \
    {dataset_id}.2013 \
    'gs://the-data-miners-cdc-bucket/the-data-miners-cdc-folder/2013.csv'
# Out:
# Waiting on bqjob_r603c7e34b5402af7_000001702b7c28f5_1 ... (85s) Current status: DONE

# %%
# Loading 2014 data onto BQ.

# %%
# !bq \
    --location=US \
    load \
    --autodetect \
    --skip_leading_rows=1 \
    --source_format=CSV \
    {dataset_id}.2014 \
    'gs://the-data-miners-cdc-bucket/the-data-miners-cdc-folder/2014.csv'
# Out:
# Waiting on bqjob_r4a5ba490a984e47c_000001702b7dfbd2_1 ... (65s) Current status: DONE

# %%
# Loading 2015 data onto BQ.

# %%
# !bq \
    --location=US \
    load \
    --autodetect \
    --skip_leading_rows=1 \
    --source_format=CSV \
    {dataset_id}.2015 \
    'gs://the-data-miners-cdc-bucket/the-data-miners-cdc-folder/2015.csv'
# Out:
# Waiting on bqjob_r72e988afe49f5720_000001702b7f8412_1 ... (64s) Current status: DONE

# %%
# sample loading from 2011 table to check for missing records. It looks correct.

# %%
# %%bigquery
# select * from cdc_staging.2011 limit 50
# Out:
#     _STATE  _GEOSTR  _DENSTR2  PRECALL    REPNUM  REPDEPTH  FMONTH  \
# 0      1.0     15.0       2.0      1.0   10170.0       9.0     1.0
# 1     45.0      7.0       2.0      1.0   80125.0      17.0     8.0
# 2     53.0     27.0       2.0      1.0   30457.0      19.0     3.0
# 3     51.0     23.0       2.0      1.0  100201.0      14.0    10.0
# 4      4.0     10.0       1.0      1.0  120443.0      24.0    12.0
# 5      4.0     10.0       1.0      1.0   30240.0      20.0     3.0
# 6      4.0     10.0       1.0      1.0   20226.0      12.0     2.0
# 7      4.0     10.0       1.0      1.0   80193.0       6.0     8.0
# 8      4.0     10.0       1.0      1.0  120329.0      18.0    12.0
# 9      4.0     10.0       1.0      1.0   20224.0      18.0     2.0
# 10     4.0     10.0       1.0      1.0   10235.0      15.0     1.0
# 11     8.0     20.0       2.0      1.0   40279.0      26.0     4.0
# 12     8.0     20.0       2.0      1.0   10250.0      11.0     1.0
# ...

# %%
# sample loading from 2012 table to check for missing records. It looks correct.

# %%
# %%bigquery
# select * from cdc_staging.2012 limit 50
# Out:
#     _STATE  _GEOSTR  _DENSTR2  PRECALL    REPNUM  REPDEPTH  FMONTH  \
# 0      8.0     19.0       2.0      1.0   10200.0       9.0     1.0
# 1     45.0      7.0       2.0      1.0   60101.0      28.0     6.0
# 2     45.0      7.0       2.0      1.0   60104.0      11.0     6.0
# 3     51.0     23.0       2.0      1.0   60145.0      10.0     6.0
# 4      4.0     10.0       1.0      1.0  110196.0      13.0    11.0
# 5      8.0     20.0       2.0      1.0   60220.0      11.0     6.0
# 6      2.0      5.0       1.0      1.0   80109.0       8.0     8.0
# 7      2.0      5.0       1.0      1.0   10051.0      26.0     1.0
# 8      2.0      5.0       1.0      1.0  100162.0      19.0    10.0
# 9      2.0      5.0       1.0      1.0   30143.0      13.0     3.0
# 10     2.0      5.0       1.0      1.0   60069.0      11.0     6.0
# 11     2.0      5.0       1.0      1.0   10067.0      20.0     1.0
# 12     2.0      5.0       1.0      1.0   20059.0      30.0     2.0
# ...

# %%
# sample loading from 2013 table to check for missing records. It looks correct.

# %%
# %%bigquery
# select * from cdc_staging.2013 limit 50
# Out:
#     _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0     51.0     3.0  b'04032013'  b'04'  b'03'  b'2013'    1200.0
# 1     13.0     6.0  b'06142013'  b'06'  b'14'  b'2013'    1200.0
# 2     23.0     5.0  b'05292013'  b'05'  b'29'  b'2013'    1200.0
# 3     20.0    12.0  b'12042013'  b'12'  b'04'  b'2013'    1200.0
# 4     37.0     2.0  b'03252013'  b'03'  b'25'  b'2013'    1200.0
# 5     37.0     7.0  b'08272013'  b'08'  b'27'  b'2013'    1200.0
# 6     37.0     4.0  b'06262013'  b'06'  b'26'  b'2013'    1200.0
# 7     37.0     5.0  b'06282013'  b'06'  b'28'  b'2013'    1200.0
# 8     37.0     4.0  b'06102013'  b'06'  b'10'  b'2013'    1200.0
# 9     37.0     8.0  b'10142013'  b'10'  b'14'  b'2013'    1200.0
# 10    37.0     4.0  b'06242013'  b'06'  b'24'  b'2013'    1200.0
# 11    37.0     2.0  b'03272013'  b'03'  b'27'  b'2013'    1200.0
# 12    37.0     6.0  b'08012013'  b'08'  b'01'  b'2013'    1200.0
# ...

# %%
# sample loading from 2014 table to check for missing records. It looks correct.

# %%
# %%bigquery
# select * from cdc_staging.2014 limit 50
# Out:
#     _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0     72.0    10.0  b'10112014'  b'10'  b'11'  b'2014'    1100.0
# 1     72.0     1.0  b'02032014'  b'02'  b'03'  b'2014'    1100.0
# 2     72.0     8.0  b'08092014'  b'08'  b'09'  b'2014'    1100.0
# 3     72.0     5.0  b'05032014'  b'05'  b'03'  b'2014'    1100.0
# 4     72.0     5.0  b'05132014'  b'05'  b'13'  b'2014'    1100.0
# 5     72.0     9.0  b'09122014'  b'09'  b'12'  b'2014'    1100.0
# 6     72.0    10.0  b'10172014'  b'10'  b'17'  b'2014'    1100.0
# 7     72.0    10.0  b'10222014'  b'10'  b'22'  b'2014'    1100.0
# 8     72.0     3.0  b'03132014'  b'03'  b'13'  b'2014'    1100.0
# 9     72.0     2.0  b'02172014'  b'02'  b'17'  b'2014'    1100.0
# 10    72.0     4.0  b'04082014'  b'04'  b'08'  b'2014'    1100.0
# 11    72.0     1.0  b'02022014'  b'02'  b'02'  b'2014'    1100.0
# 12    72.0     3.0  b'03152014'  b'03'  b'15'  b'2014'    1100.0
# ...

# %%
# sample loading from 2015 table to check for missing records. It looks correct.

# %%
# %%bigquery
# select * from cdc_staging.2015 limit 50
# Out:
#     _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0     24.0     6.0  b'06032015'  b'06'  b'03'  b'2015'    1100.0
# 1      6.0     4.0  b'07022015'  b'07'  b'02'  b'2015'    1200.0
# 2      6.0     1.0  b'05132015'  b'05'  b'13'  b'2015'    1200.0
# 3      4.0    10.0  b'11042015'  b'11'  b'04'  b'2015'    1100.0
# 4      6.0     7.0  b'11132015'  b'11'  b'13'  b'2015'    1200.0
# 5      6.0    10.0  b'11302015'  b'11'  b'30'  b'2015'    1200.0
# 6     34.0     6.0  b'06142015'  b'06'  b'14'  b'2015'    1100.0
# 7      6.0     1.0  b'06142015'  b'06'  b'14'  b'2015'    1200.0
# 8     47.0    11.0  b'12102015'  b'12'  b'10'  b'2015'    1100.0
# 9     34.0     8.0  b'08042015'  b'08'  b'04'  b'2015'    1100.0
# 10    15.0     4.0  b'04112015'  b'04'  b'11'  b'2015'    1200.0
# 11    33.0     2.0  b'02272015'  b'02'  b'27'  b'2015'    1200.0
# 12    21.0     1.0  b'01212015'  b'01'  b'21'  b'2015'    1200.0
# ...

# %%
# The first query is for the 2011 data table.
# The query below looks at the first 20 entries for when the _STATE is 48. _STATE 48 refers to Texas. 
# The data is ordered by IMONTH in ascending order. IMONTH refers to the month when the participant was interviewed.
# This query separates health data for the state of Texas so we can examine local health issues.

# %%
# %%bigquery
# select * from cdc_staging.2011 where _STATE=48 order by IMONTH limit 20
# Out:
#     _STATE  _GEOSTR  _DENSTR2  PRECALL   REPNUM  REPDEPTH  FMONTH  \
# 0     48.0     19.0       2.0      1.0  10600.0      14.0     1.0
# 1     48.0      9.0       2.0      1.0  10330.0      27.0     1.0
# 2     48.0      3.0       2.0      1.0  10067.0       2.0     1.0
# 3     48.0      3.0       2.0      1.0  10084.0      30.0     1.0
# 4     48.0     15.0       2.0      1.0  10476.0       7.0     1.0
# 5     48.0     19.0       2.0      1.0  10604.0      16.0     1.0
# 6     48.0     19.0       2.0      1.0  10598.0      24.0     1.0
# 7     48.0      4.0       1.0      1.0  10108.0      23.0     1.0
# 8     48.0     19.0       1.0      1.0  10580.0      28.0     1.0
# 9     48.0      2.0       2.0      1.0  10044.0      20.0     1.0
# 10    48.0      4.0       1.0      1.0  10124.0       7.0     1.0
# 11    48.0      7.0       2.0      1.0  10195.0      28.0     1.0
# 12    48.0     19.0       1.0      1.0  10600.0      28.0     1.0
# ...

# %%
# The second query is for the 2012 data table.
# The query shows the first 20 rows of data, where the number of attempts is greater than or equal to 5
# The number of attempts refers to the number of times the participant has completed the surveys in the past
# This dataset includes many individuals who have completed the survey for multiple years in a row. These individuals may be markedly different from the average population and should be examined separately.

# %%
# %%bigquery
# select * from cdc_staging.2012 where NATTMPTS>=5 order by IMONTH limit 20
# Out:
#     _STATE  _GEOSTR  _DENSTR2  PRECALL    REPNUM  REPDEPTH  FMONTH  \
# 0      6.0     99.0       9.0      1.0  100517.0      28.0    10.0
# 1      6.0     99.0       9.0      1.0  100109.0      19.0    10.0
# 2      6.0     99.0       9.0      1.0  100070.0       4.0    10.0
# 3      6.0     99.0       9.0      1.0  100183.0      10.0    10.0
# 4      2.0      6.0       1.0      1.0   10087.0      28.0     1.0
# 5      6.0     99.0       9.0      1.0  100305.0      28.0    10.0
# 6      6.0     99.0       9.0      1.0  100179.0      30.0    10.0
# 7      6.0     99.0       9.0      1.0   10467.0       2.0     1.0
# 8      6.0     99.0       9.0      1.0   10115.0      25.0     1.0
# 9      6.0     99.0       9.0      1.0  100243.0      25.0    10.0
# 10     6.0     99.0       9.0      1.0   10317.0       7.0     1.0
# 11     6.0     99.0       9.0      1.0  100398.0       2.0    10.0
# 12     6.0     99.0       9.0      1.0  100064.0      24.0    10.0
# ...

# %%
# The third query is for the 2013 data table.
# The query shows the Sequence Number (SEQNO) and State for people who were tested positive for HIV (HIVTST6=1), ordered by state. 
# The first 20 rows all are from state 1, which is Alabama
# HIV testing and management is known to be understudied in rural areas, so we separated out the data from Alabama, a predominantly rural state. We can then examine how data from Alabama residents may differ from residents of more urban states.

# %%
# %%bigquery
# select _STATE, SEQNO, HIVTST6 from cdc_staging.2013 where HIVTST6=1 AND _STATE=1
# Out:
#       _STATE         SEQNO  HIVTST6
# 0        1.0  2.013001e+09      1.0
# 1        1.0  2.013004e+09      1.0
# 2        1.0  2.013004e+09      1.0
# 3        1.0  2.013001e+09      1.0
# 4        1.0  2.013003e+09      1.0
# ...      ...           ...      ...
# 1840     1.0  2.013001e+09      1.0
# 1841     1.0  2.013002e+09      1.0
# 1842     1.0  2.013004e+09      1.0
# 1843     1.0  2.013002e+09      1.0
# 1844     1.0  2.013003e+09      1.0
#
# [1845 rows x 3 columns]

# %%
# The fourth query is for the 2014 data table.
# The query shows the sequence number for the first 20 rows for people who said yes to: "During the past 12 months, have you had either a flu shot or a flu vaccine that was sprayed in your nose?", ordered by the month filed.
# This query allowed us to examine the unique identifiers for respondants who receive the flu vaccine. Accessing a unique identifier is a useful step if we need to request additional data from the CDC.

# %%
# %%bigquery
# select SEQNO, FLUSHOT6 from cdc_staging.2014 where FLUSHOT6=1 order by FMONTH limit 20
# Out:
#            SEQNO  FLUSHOT6
# 0   2.014007e+09       1.0
# 1   2.014001e+09       1.0
# 2   2.014007e+09       1.0
# 3   2.014000e+09       1.0
# 4   2.014000e+09       1.0
# 5   2.014007e+09       1.0
# 6   2.014007e+09       1.0
# 7   2.014000e+09       1.0
# 8   2.014018e+09       1.0
# 9   2.014001e+09       1.0
# 10  2.014007e+09       1.0
# 11  2.014007e+09       1.0
# 12  2.014013e+09       1.0
# 13  2.014000e+09       1.0
# 14  2.014000e+09       1.0
# 15  2.014007e+09       1.0
# 16  2.014007e+09       1.0
# 17  2.014000e+09       1.0
# 18  2.014005e+09       1.0
# 19  2.014001e+09       1.0

# %%
#This query searches the 2015 data. 
#This query shows the sequence data for the first 10 rows where respondants answered "always" to "How often do you use your seatbelt?", ordered by the month filed.
#This data could show patterns between vehicle accidents and seat belt use.

# %%
# %%bigquery
# select * from cdc_staging.2015 where SEATBELT = 1 order by FMONTH limit 20
# Out:
#     _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0     48.0     1.0  b'01202015'  b'01'  b'20'  b'2015'    1100.0
# 1     30.0     1.0  b'01102015'  b'01'  b'10'  b'2015'    1100.0
# 2     35.0     1.0  b'02012015'  b'02'  b'01'  b'2015'    1200.0
# 3     37.0     1.0  b'01162015'  b'01'  b'16'  b'2015'    1100.0
# 4     31.0     1.0  b'02192015'  b'02'  b'19'  b'2015'    1100.0
# 5     39.0     1.0  b'02102015'  b'02'  b'10'  b'2015'    1100.0
# 6     48.0     1.0  b'01132015'  b'01'  b'13'  b'2015'    1100.0
# 7     21.0     1.0  b'01162015'  b'01'  b'16'  b'2015'    1100.0
# 8     36.0     1.0  b'01132015'  b'01'  b'13'  b'2015'    1100.0
# 9      6.0     1.0  b'05172015'  b'05'  b'17'  b'2015'    1100.0
# 10    21.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 11    51.0     1.0  b'02062015'  b'02'  b'06'  b'2015'    1100.0
# 12    19.0     1.0  b'01182015'  b'01'  b'18'  b'2015'    1100.0
# ...
